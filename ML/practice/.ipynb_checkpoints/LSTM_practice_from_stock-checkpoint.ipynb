# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv('../data/20140101_20211001_PM10_observed.csv', header = None, names = ['date', 'PM10'])
data.head()
# Out:
#          date  PM10
# 0  2014-01-01   106
# 1  2014-01-02    85
# 2  2014-01-03    59
# 3  2014-01-04    57
# 4  2014-01-05    33

# %% [markdown]
# # Compute Mid Price

# %%
mid_prices = data['PM10'].values

# %% [markdown]
# # Create Windows

# %%
seq_len = 50
sequence_length = seq_len + 1

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])

# %% [markdown]
# # Normalize Data

# %%
normalized_data = []
for window in result:
    normalized_window = [((int(p) / int(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.9))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :-1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1]

x_test = result[row:, :-1]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1]

x_train.shape, x_test.shape
# Out:
# ((2502, 50, 1), (278, 50, 1))

# %% [markdown]
# # Build a Model

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1)))

model.add(LSTM(64, return_sequences=False))

model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='rmsprop')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 39,905
# Trainable params: 39,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)
# Out:
# Epoch 1/20
# 251/251 [==============================] - 9s 27ms/step - loss: 0.2765 - val_loss: 0.5725
# Epoch 2/20
# 251/251 [==============================] - 6s 24ms/step - loss: 0.2322 - val_loss: 0.4820
# Epoch 3/20
# 251/251 [==============================] - 6s 24ms/step - loss: 0.2017 - val_loss: 0.4730
# Epoch 4/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1970 - val_loss: 0.4903
# Epoch 5/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1908 - val_loss: 0.4907
# Epoch 6/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1913 - val_loss: 0.4753
# Epoch 7/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1919 - val_loss: 0.4684
# Epoch 8/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1889 - val_loss: 0.4749
# Epoch 9/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1891 - val_loss: 0.4790
# Epoch 10/20
# 251/251 [==============================] - 6s 24ms/step - loss: 0.1884 - val_loss: 0.4877
# Epoch 11/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1892 - val_loss: 0.4813
# Epoch 12/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1859 - val_loss: 0.4897
# Epoch 13/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1869 - val_loss: 0.4693
# Epoch 14/20
# 251/251 [==============================] - 7s 26ms/step - loss: 0.1877 - val_loss: 0.4809
# Epoch 15/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1863 - val_loss: 0.4771
# Epoch 16/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1855 - val_loss: 0.4734
# Epoch 17/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1857 - val_loss: 0.4727
# Epoch 18/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1866 - val_loss: 0.4903
# Epoch 19/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1847 - val_loss: 0.5023
# Epoch 20/20
# 251/251 [==============================] - 6s 25ms/step - loss: 0.1861 - val_loss: 0.4834

# %% [markdown]
# # Prediction

# %%
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(25, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend()
plt.show()
